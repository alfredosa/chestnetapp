# %%
# !pip install dnspython
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 269.1/269.1 kB 4.4 MB/s eta 0:00:00 MB/s eta 0:00:01
# ...

# %%
import streamlit as st
import pymongo
import pandas as pd

myclient = pymongo.MongoClient("mongodb+srv://alf-deepen:GWvfeEk5w5TgcXSa@cluster0.ixkyxa7.mongodb.net/?retryWrites=true&w=majority")
mydb = myclient["papers"]
mycol = mydb["researchpapers"]

mydoc = mycol.find({})
df = pd.DataFrame(list(mydoc))
strdf = df.astype(str)

# %%
playing = strdf.sample(50)

# %%
for key,value in strdf.iterrows():
     if len(value.PMID)>6 and len(value.PMID)<10:
         value['_id:'] = value.PMID
     elif value.PMID == 'nan' and len(value['_id']) < 10:
         value['_id:'] = value["_id"]

# %%
newdf = strdf

# %%
newdf.drop(columns='',inplace=True)

# %%
newdf
# Out:
#                              _id      PMID  \
# 0       62f7b7e04c208a014ff2b53a  35912857
# 1       62f7b7e04c208a014ff2b53b  35911768
# 2       62f7b7e04c208a014ff2b53c  35911740
# 3       62f7b7e04c208a014ff2b53d  35910379
# 4       62f7b7e04c208a014ff2b53e  35909127
# ...                          ...       ...
# 146571                  35502031       nan
# 146572                  35501327       nan
# 146573                  35501315       nan
# 146574                  35500344       nan
# 146575                  35500101       nan
#
#                                                  abstract  \
# 0       Immunomodulation holds therapeutic promise aga...
# 1       Microglia are important resident immune cells ...
# 2       Regulatory T cells (Tregs) are normally born i...
# 3       Preclinical data indicate that fingolimod impr...
# 4       Infections by viruses including severe acute r...
# ...                                                   ...
# ...

# %%
newdf['_id'] = newdf['_id:']

# %%
newdf.drop(columns='PMID', inplace=True)

# %%
newdf.drop_duplicates(subset=['_id'],inplace=True)

# %%
for i in newdf.articleTitle:
    if i.startswith('{'):
        i = i.split("'#text'")[1][:-1]

# %%
string = ": ASDASD"
if string.startswith(':'):
    print(string[1:])
# Out:
#  ASDASD

# %%
for key,value in newdf.iterrows():
    if value['articleTitle'].startswith(':'):
        value.articleTitle = value['articleTitle'][1:]

# %%
newdf
# Out:
#              _id                                           abstract  \
# 0       35912857  Immunomodulation holds therapeutic promise aga...
# 1       35911768  Microglia are important resident immune cells ...
# 2       35911740  Regulatory T cells (Tregs) are normally born i...
# 3       35910379  Preclinical data indicate that fingolimod impr...
# 4       35909127  Infections by viruses including severe acute r...
# ...          ...                                                ...
# 146571  35502031  To evaluate the agreement between the biometri...
# 146572  35501327  Due to excessive elongation of the eyeball, my...
# 146573  35501315  High-performance quantum memory for quantized ...
# 146574  35500344  Constructing catalysts with simple structures,...
# 146575  35500101  Structural colors based on the macro- or nanos...
#
#                                              articleTitle  \
# 0       Neuroprotection against ischemic stroke requir...
# ...

# %%
import json
records = json.loads(newdf.to_json(orient='records'))

# %%
mydb = myclient["cleanpapers"]
mycol = mydb["cleanedf"]

# %%
import numpy as np
splitted = np.array_split(records,10)

# %%
# Out:
# [{'_id': '35912857',
# ...

# %%
for i in splitted:
    try:
        mycol.insert_many(list(i))
        print('success printing element')
    except:
        print('already in DBs')
# Out:
# already in DBs
# already in DBs
# already in DBs
# already in DBs
# already in DBs
# success printing element
# success printing element
# success printing element
# success printing element
# success printing element
